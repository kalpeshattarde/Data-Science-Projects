# %% [markdown]
# # Graphura Instagram Content Intelligence

# %% [markdown]
# #### 1. INTRODUCTION
#
# Project Objective
#
# The objective of this machine learning system is to predict the performance of Instagram posts and support data-driven content planning for Graphura.
# Each post is classified into one of three performance categories based on historical engagement rate thresholds:
#
# -High Performance
# -Medium Performance
# -Low Performance

# %% [markdown]
# ## 1. Importing essential python libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Dataset Loading

# %%
data = pd.read_csv("Graphura Instagram Data.csv")
data.head()
# Out:
#    Post ID   Platform  Duration (sec)        Date Post type  Views  Reach  \
# 0        1  Instagram               0  11-04-2025  carousel   1623    213
# 1        2  Instagram              39  02-02-2026      reel    225    146
# 2        3  Instagram               0  02-01-2026  carousel    130     45
# 3        4  Instagram               0  31-01-2026     image    113     54
# 4        5  Instagram               0  30-01-2026     image    107     56
#
#    Likes  Shares  Follows  Comments  Saves  \
# 0     32       0        0         0      0
# 1     13       0        0         0      0
# 2      6       0        0         0      0
# 3      6       0        0         0      0
# 4      7       0        0         0      0
#
#                                              Hashtag
# 0  #SocialMediaGrowth #brewyourbrand #cafebussine...
# 1        #instagram #facebook #twitter #collobration
# 2  #ProductDesign #CleanAirVibes #HealthyLiving #...
# 3  #IndianCoastGuardDay #MaritimeSafety #National...
# 4  #GoRocketFast #BusinessGrowth #DigitalMarketin...

# %% [markdown]
# ## 3. Data Cleaning & Preprocessing

# %%
data.info()
data.isnull().sum()
data.columns = data.columns.str.strip()
data.fillna('0',inplace=True)
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Post ID         85 non-null     int64
#  1   Platform        85 non-null     object
#  2   Duration (sec)  85 non-null     int64
#  3   Date            85 non-null     object
#  4   Post type       85 non-null     object
#  5   Views           85 non-null     int64
#  6   Reach           85 non-null     int64
#  7   Likes           85 non-null     int64
#  8   Shares          85 non-null     int64
#  9   Follows         85 non-null     int64
#  10  Comments        85 non-null     int64
#  11  Saves           85 non-null     int64
#  12  Hashtag         84 non-null     object
# dtypes: int64(9), object(4)
# memory usage: 8.8+ KB
#    Post ID   Platform  Duration (sec)        Date Post type  Views  Reach  \
# 0        1  Instagram               0  11-04-2025  carousel   1623    213
# 1        2  Instagram              39  02-02-2026      reel    225    146
# 2        3  Instagram               0  02-01-2026  carousel    130     45
# 3        4  Instagram               0  31-01-2026     image    113     54
# 4        5  Instagram               0  30-01-2026     image    107     56
#
#    Likes  Shares  Follows  Comments  Saves  \
# 0     32       0        0         0      0
# 1     13       0        0         0      0
# 2      6       0        0         0      0
# 3      6       0        0         0      0
# 4      7       0        0         0      0
#
#                                              Hashtag
# 0  #SocialMediaGrowth #brewyourbrand #cafebussine...
# 1        #instagram #facebook #twitter #collobration
# 2  #ProductDesign #CleanAirVibes #HealthyLiving #...
# 3  #IndianCoastGuardDay #MaritimeSafety #National...
# 4  #GoRocketFast #BusinessGrowth #DigitalMarketin...

# %%
data["Post type"].fillna(0)
# Out:
# 0     carousel
# 1         reel
# 2     carousel
# 3        image
# 4        image
#         ...
# 80       image
# 81    carousel
# 82       image
# 83       image
# 84       image
# Name: Post type, Length: 85, dtype: object

# %%
# Replace 0 with NaN
data["Duration (sec)"] = data["Duration (sec)"].replace(0, np.nan)

data["Duration (sec)"] = data["Duration (sec)"].fillna(
    data["Duration (sec)"].median()
)

# Change datatype to float
data["Duration (sec)"] = data["Duration (sec)"].astype(float)

# %%
data["Date"] = pd.to_datetime(
    data["Date"],
    format="mixed",
    dayfirst=True,
    errors="coerce"
)

data = data.copy()
data["Day"] = data["Date"].dt.day
data["Month"] = data["Date"].dt.month
data["Weekday"] = data["Date"].dt.weekday
data.drop(columns=["Date"], inplace=True)

# %%
data.head()
# Out:
#    Post ID   Platform  Duration (sec) Post type  Views  Reach  Likes  Shares  \
# 0        1  Instagram            15.0  carousel   1623    213     32       0
# 1        2  Instagram            39.0      reel    225    146     13       0
# 2        3  Instagram            15.0  carousel    130     45      6       0
# 3        4  Instagram            15.0     image    113     54      6       0
# 4        5  Instagram            15.0     image    107     56      7       0
#
#    Follows  Comments  Saves  \
# 0        0         0      0
# 1        0         0      0
# 2        0         0      0
# 3        0         0      0
# 4        0         0      0
#
#                                              Hashtag  Day  Month  Weekday
# 0  #SocialMediaGrowth #brewyourbrand #cafebussine...   11      4        4
# 1        #instagram #facebook #twitter #collobration    2      2        0
# 2  #ProductDesign #CleanAirVibes #HealthyLiving #...    2      1        4
# 3  #IndianCoastGuardDay #MaritimeSafety #National...   31      1        5
# 4  #GoRocketFast #BusinessGrowth #DigitalMarketin...   30      1        4

# %% [markdown]
# ## 4.Feature Engineering`

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Post ID         85 non-null     int64
#  1   Platform        85 non-null     object
#  2   Duration (sec)  85 non-null     float64
#  3   Post type       85 non-null     object
#  4   Views           85 non-null     int64
#  5   Reach           85 non-null     int64
#  6   Likes           85 non-null     int64
#  7   Shares          85 non-null     int64
#  8   Follows         85 non-null     int64
#  9   Comments        85 non-null     int64
#  10  Saves           85 non-null     int64
#  11  Hashtag         85 non-null     object
#  12  Day             85 non-null     int32
#  13  Month           85 non-null     int32
#  14  Weekday         85 non-null     int32
# dtypes: float64(1), int32(3), int64(8), object(3)
# memory usage: 9.1+ KB

# %%
data["Hashtag_Count"] = data["Hashtag"].fillna("").str.count("#")

# %%
data["Engagement Rate by Reach (%)"] = (
    (
        data["Likes"].fillna(0)
        + data["Comments"].fillna(0)
        + data["Shares"].fillna(0)
        + data["Saves"].fillna(0)
    )
    / data["Reach"].replace(0, np.nan)
) * 100

data["Engagement Rate by Reach (%)"] = data["Engagement Rate by Reach (%)"].clip(upper=100)

# %%
data["Engagement Rate by Views (%)"] = (
    (
        data["Likes"].fillna(0)
        + data["Comments"].fillna(0)
        + data["Shares"].fillna(0)
        + data["Reach"].fillna(0)
        + data["Saves"].fillna(0)
    )
    / data["Views"].replace(0, np.nan)
) * 100

data["Engagement Rate by Views (%)"] = data["Engagement Rate by Views (%)"].clip(upper=100)

# %%
bins = [0, 10,25, 100]
labels = ["Low", "Medium", "High"]

data["Performance_Class"] = pd.cut(
    data["Engagement Rate by Views (%)"],
    bins=bins,
    labels=labels,
    right=False
)

# %%
data = data.drop(columns=["Platform", "Hashtag"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Post ID                       85 non-null     int64
#  1   Duration (sec)                85 non-null     float64
#  2   Post type                     85 non-null     object
#  3   Views                         85 non-null     int64
#  4   Reach                         85 non-null     int64
#  5   Likes                         85 non-null     int64
#  6   Shares                        85 non-null     int64
#  7   Follows                       85 non-null     int64
#  8   Comments                      85 non-null     int64
#  9   Saves                         85 non-null     int64
#  10  Day                           85 non-null     int32
#  11  Month                         85 non-null     int32
#  12  Weekday                       85 non-null     int32
#  13  Hashtag_Count                 85 non-null     int64
#  14  Engagement Rate by Reach (%)  85 non-null     float64
#  15  Engagement Rate by Views (%)  85 non-null     float64
#  16  Performance_Class             85 non-null     category
# dtypes: category(1), float64(3), int32(3), int64(9), object(1)
# memory usage: 10.0+ KB

# %%
data.columns
# Out:
# Index(['Post ID', 'Duration (sec)', 'Post type', 'Views', 'Reach', 'Likes',
#        'Shares', 'Follows', 'Comments', 'Saves', 'Day', 'Month', 'Weekday',
#        'Hashtag_Count', 'Engagement Rate by Reach (%)',
#        'Engagement Rate by Views (%)', 'Performance_Class'],
#       dtype='object')

# %%
data.head()
# Out:
#    Post ID  Duration (sec) Post type  Views  Reach  Likes  Shares  Follows  \
# 0        1            15.0  carousel   1623    213     32       0        0
# 1        2            39.0      reel    225    146     13       0        0
# 2        3            15.0  carousel    130     45      6       0        0
# 3        4            15.0     image    113     54      6       0        0
# 4        5            15.0     image    107     56      7       0        0
#
#    Comments  Saves  Day  Month  Weekday  Hashtag_Count  \
# 0         0      0   11      4        4              8
# 1         0      0    2      2        0              4
# 2         0      0    2      1        4              4
# 3         0      0   31      1        5              4
# 4         0      0   30      1        4              4
#
#    Engagement Rate by Reach (%)  Engagement Rate by Views (%)  \
# 0                     15.023474                     15.095502
# 1                      8.904110                     70.666667
# 2                     13.333333                     39.230769
# 3                     11.111111                     53.097345
# 4                     12.500000                     58.878505
#
#   Performance_Class
# 0            Medium
# 1              High
# 2              High
# 3              High
# 4              High

# %% [markdown]
# # Feature Selection

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = data.select_dtypes(include=["int64", "float64"]) \
           .drop(columns=["Engagement Rate by Views (%)"], errors="ignore") \
           .corr()


plt.figure(figsize=(14,10))
sns.heatmap(corr, cmap="coolwarm", center=0)
plt.title("Liquidity Channel Correlation Matrix")
plt.show()

# %%
from sklearn.model_selection import train_test_split

xc = data.drop("Performance_Class", axis=1)
yc = data["Performance_Class"]

xctrain, xctest, yctrain, yctest = train_test_split(xc,yc,test_size=0.2,random_state=42,stratify=yc)

# %%
num_cols = [
    "Duration (sec)", "Views", "Reach", "Likes", "Shares",
    "Follows", "Comments", "Saves", "Hashtag_Count",
    "Engagement Rate by Views (%)",
    "Engagement Rate by Reach (%)"
]

cat_cols = ["Post type"]

target = "Performance_Class"

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

num_pipe = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

cat_pipe = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(
        handle_unknown="ignore",
        sparse_output=False   # IMPORTANT
    ))
])

preprocessor = ColumnTransformer([
    ("num", num_pipe, num_cols),
    ("cat", cat_pipe, cat_cols),
])

# %%
xctrain_processed = preprocessor.fit_transform(xctrain)
xctest_processed = preprocessor.transform(xctest)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

# %%
cat_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(
        handle_unknown="ignore",
        sparse_output=False   # CRITICAL FIX
    ))
])

# %%
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ("num", num_pipeline, num_cols),
        ("cat", cat_pipeline, cat_cols),
    ],
    remainder="drop"
)

# %% [markdown]
# # CLASSIFICATION MODELS (post performance category)

# %% [markdown]
# #### Model Training, Model Evaluation & Model Training

# %%
from sklearn.metrics import accuracy_score, classification_report

def evaluate_model(model, xctest, yctest, name):
    preds = model.predict(xctest)
    acc = accuracy_score(yctest, preds)
    
    print(f"\n{name}")
    print("Accuracy:", acc)
    print(classification_report(yctest, preds))
    
    return acc

# %% [markdown]
# ## 1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

log_pipe = Pipeline([
    ("preprocessing", preprocessor),
    ("model", LogisticRegression(max_iter=200))
])


log_params = {
    "model__C": [0.01, 0.1, 1, 10, 100],
    "model__solver": ["lbfgs"],
    "model__class_weight": [None, "balanced"]
}


log_grid = GridSearchCV(
    log_pipe,
    log_params,
    cv=5,
    scoring="accuracy"
)

log_grid.fit(xctrain, yctrain)
best_log = log_grid.best_estimator_

evaluate_model(best_log, xctest, yctest, "Logistic Regression")
# Out:
# Logistic Regression
# Accuracy: 0.9411764705882353
#               precision    recall  f1-score   support
#
#         High       0.92      1.00      0.96        12
#       Medium       1.00      0.80      0.89         5
#
#     accuracy                           0.94        17
#    macro avg       0.96      0.90      0.92        17
# weighted avg       0.95      0.94      0.94        17
# 0.9411764705882353

# %%
results = pd.DataFrame(log_grid.cv_results_)

plt.figure()
plt.plot(results["param_model__C"], results["mean_test_score"], marker="o")
plt.xscale("log")
plt.xlabel("C (Regularization Strength)")
plt.ylabel("Accuracy")
plt.title("Logistic Regression – Hyperparameter Tuning")
plt.show()

# %% [markdown]
# ### 2. K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_pipe = Pipeline([
    ("preprocessing", preprocessor),
    ("model", KNeighborsClassifier())
])


knn_params = {
    "model__n_neighbors": [3, 5, 7, 9, 11, 15],
    "model__weights": ["uniform", "distance"]
}


knn_grid = GridSearchCV(
    knn_pipe,
    knn_params,
    cv=5,
    scoring="accuracy"
)

knn_grid.fit(xctrain, yctrain)
best_knn = knn_grid.best_estimator_


evaluate_model(best_knn, xctest, yctest, "KNN")
# Out:
# KNN
# Accuracy: 0.9411764705882353
#               precision    recall  f1-score   support
#
#         High       0.92      1.00      0.96        12
#       Medium       1.00      0.80      0.89         5
#
#     accuracy                           0.94        17
#    macro avg       0.96      0.90      0.92        17
# weighted avg       0.95      0.94      0.94        17
# 0.9411764705882353

# %% [markdown]
# ### 3. Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

gnb_pipe = Pipeline([
    ("preprocessing", preprocessor),
    ("model", GaussianNB())
])


gnb_params = {
    "model__var_smoothing": [1e-9, 1e-8, 1e-7, 1e-6]
}


gnb_grid = GridSearchCV(
    gnb_pipe,
    gnb_params,
    cv=5,
    scoring="accuracy"
)

gnb_grid.fit(xctrain, yctrain)
best_gnb = gnb_grid.best_estimator_


evaluate_model(best_gnb, xctest, yctest, "Gaussian Naive Bayes")
# Out:
# Gaussian Naive Bayes
# Accuracy: 0.9411764705882353
#               precision    recall  f1-score   support
#
#         High       1.00      0.92      0.96        12
#       Medium       0.83      1.00      0.91         5
#
#     accuracy                           0.94        17
#    macro avg       0.92      0.96      0.93        17
# weighted avg       0.95      0.94      0.94        17
# 0.9411764705882353

# %%
results = pd.DataFrame(gnb_grid.cv_results_)

plt.figure()
plt.plot(results["param_model__var_smoothing"], results["mean_test_score"], marker="o")
plt.xscale("log")
plt.xlabel("var_smoothing")
plt.ylabel("Accuracy")
plt.title("GaussianNB – Hyperparameter Tuning")
plt.show()

# %% [markdown]
# ### 4. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dt_pipe = Pipeline([
    ("preprocessing", preprocessor),
    ("model", DecisionTreeClassifier(random_state=42))
])


dt_params = {
    "model__max_depth": [None, 5, 10, 20],
    "model__min_samples_split": [2, 5, 10]
}


dt_grid = GridSearchCV(
    dt_pipe,
    dt_params,
    cv=5,
    scoring="accuracy"
)

dt_grid.fit(xctrain, yctrain)
best_dt = dt_grid.best_estimator_


evaluate_model(best_dt, xctest, yctest, "Decision Tree")
# Out:
# Decision Tree
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00        12
#       Medium       1.00      1.00      1.00         5
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17
# 1.0

# %% [markdown]
# ### 5. Support Vector Machine(SVC)

# %%
from sklearn.svm import SVC

svc_pipe = Pipeline([
    ("preprocessing", preprocessor),
    ("model", SVC())
])


svc_params = {
    "model__C": [0.1, 1, 10, 100],
    "model__kernel": ["linear", "rbf"],
    "model__gamma": ["scale", "auto"]
}


svc_grid = GridSearchCV(
    svc_pipe,
    svc_params,
    cv=5,
    scoring="accuracy"
)

svc_grid.fit(xctrain, yctrain)
best_svc = svc_grid.best_estimator_


evaluate_model(best_svc, xctest, yctest, "Support Vector Classifier")
# Out:
# Support Vector Classifier
# Accuracy: 0.9411764705882353
#               precision    recall  f1-score   support
#
#         High       0.92      1.00      0.96        12
#       Medium       1.00      0.80      0.89         5
#
#     accuracy                           0.94        17
#    macro avg       0.96      0.90      0.92        17
# weighted avg       0.95      0.94      0.94        17
# 0.9411764705882353

# %%
import pandas as pd
import matplotlib.pyplot as plt

results = pd.DataFrame(svc_grid.cv_results_)

plt.figure()
plt.plot(results["param_model__C"], results["mean_test_score"], marker="o")
plt.xscale("log")
plt.xlabel("C")
plt.ylabel("Accuracy")
plt.title("SVC – Hyperparameter Tuning")
plt.show()

# %% [markdown]
# ### 6. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_pipe = Pipeline([
    ("preprocessing", preprocessor),
    ("model", RandomForestClassifier(random_state=42))
])


rf_params = {
    "model__n_estimators": [100, 200, 300],
    "model__max_depth": [None, 10, 20],
    "model__min_samples_split": [2, 5]
}


rf_grid = GridSearchCV(
    rf_pipe,
    rf_params,
    cv=5,
    scoring="accuracy",
    n_jobs=-1
)

rf_grid.fit(xctrain, yctrain)
best_rf = rf_grid.best_estimator_


evaluate_model(best_rf, xctest, yctest, "Random Forest")
# Out:
# Random Forest
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00        12
#       Medium       1.00      1.00      1.00         5
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17
# 1.0

# %%
results = pd.DataFrame(rf_grid.cv_results_)

plt.figure()
plt.plot(results["param_model__n_estimators"], results["mean_test_score"], marker="o")
plt.xlabel("Number of Trees")
plt.ylabel("Accuracy")
plt.title("Random Forest – Hyperparameter Tuning")
plt.show()

# %% [markdown]
# ### 7. Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb_pipe = Pipeline([
    ("preprocessing", preprocessor),
    ("model", GradientBoostingClassifier(random_state=42))
])


gb_params = {
    "model__n_estimators": [100, 200],
    "model__learning_rate": [0.01, 0.1],
    "model__max_depth": [3, 5]
}


gb_grid = GridSearchCV(
    gb_pipe,
    gb_params,
    cv=5,
    scoring="accuracy"
)

gb_grid.fit(xctrain, yctrain)
best_gb = gb_grid.best_estimator_


evaluate_model(best_gb, xctest, yctest, "Gradient Boosting")
# Out:
# Gradient Boosting
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00        12
#       Medium       1.00      1.00      1.00         5
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17
# 1.0

# %%
import pandas as pd
from sklearn.metrics import accuracy_score

final_results = pd.DataFrame([
    ["Logistic Regression", accuracy_score(yctest, best_log.predict(xctest))],
    ["KNN", accuracy_score(yctest, best_knn.predict(xctest))],
    ["Decision Tree", accuracy_score(yctest, best_dt.predict(xctest))],
    ["Random Forest", accuracy_score(yctest, best_rf.predict(xctest))],
    ["Gradient Boosting", accuracy_score(yctest, best_gb.predict(xctest))],
    ["SVC", accuracy_score(yctest, best_svc.predict(xctest))],
    ["GaussianNB", accuracy_score(yctest, best_gnb.predict(xctest))]
], columns=["Model", "Accuracy"])

final_results.sort_values("Accuracy", ascending=False)
# Out:
#                  Model  Accuracy
# 2        Decision Tree  1.000000
# 4    Gradient Boosting  1.000000
# 3        Random Forest  1.000000
# 1                  KNN  0.941176
# 0  Logistic Regression  0.941176
# 5                  SVC  0.941176
# 6           GaussianNB  0.941176

# %%
best_model = best_rf   # or best_log, best_svc, best_gb, etc.

# %% [markdown]
# ## CLASSIFICATION MANUAL TESTING (Risk Regime)

# %% [markdown]
# #### Low Quality Contents → Low | 🟡 Medium Quality Contents → Medium | 🔴 High Quality Contents → High

# %% [markdown]
# ### Test Case 1 – Low Quality Content

# %%
import pandas as pd

low_case = pd.DataFrame([{
    "Duration (sec)": 15,
    "Views": 200,
    "Reach": 180,
    "Likes": 5,
    "Shares": 0,
    "Follows": 0,
    "Comments": 1,
    "Saves": 0,
    "Hashtag_Count": 1,
    "Engagement Rate by Views (%)": 2.5,
    "Engagement Rate by Reach (%)": 2.0,
    "Post type": "image",
    "PostType_carousel": False,
    "PostType_image": True,
    "PostType_reel": False
}])

print("Low Quality Content", best_model.predict(low_case))
# Out:
# Low Quality Content ['Medium']

# %% [markdown]
# ### Test Case 2 – Medium Quality Content

# %%
medium_case = pd.DataFrame([{
    "Duration (sec)": 30,
    "Views": 1200,
    "Reach": 1000,
    "Likes": 120,
    "Shares": 10,
    "Follows": 8,
    "Comments": 15,
    "Saves": 20,
    "Hashtag_Count": 4,
    "Engagement Rate by Views (%)": 10.0,
    "Engagement Rate by Reach (%)": 12.0,
    "Post type": "carousel",
    "PostType_carousel": True,
    "PostType_image": False,
    "PostType_reel": False
}])

print("Medium Quality Content:", best_model.predict(medium_case))
# Out:
# Medium Quality Content: ['Medium']

# %% [markdown]
# ### Test Case 3 – High Quality Content

# %%
high_case = pd.DataFrame([{
    "Duration (sec)": 45,
    "Views": 12000,
    "Reach": 10000,
    "Likes": 1800,
    "Shares": 300,
    "Follows": 200,
    "Comments": 250,
    "Saves": 500,
    "Hashtag_Count": 6,
    "Engagement Rate by Views (%)": 25.0,
    "Engagement Rate by Reach (%)": 28.0,
    "Post type": "reel",
    "PostType_carousel": False,
    "PostType_image": False,
    "PostType_reel": True
}])

print("High Quality Content:", best_model.predict(high_case))
# Out:
# High Quality Content: ['Medium']

# %% [markdown]
# # Deployment

# %%
EXPECTED_COLUMNS = xctrain.columns.tolist()

def safe_input(df):
    for col in EXPECTED_COLUMNS:
        if col not in df:
            df[col] = None
    return df[EXPECTED_COLUMNS]

# %%
import pandas as pd

user_input = pd.DataFrame([{
    "Platform": "Instagram",
    "Views": 1200,
    "Likes": 140,
    "PostType_reel": True
    # MANY fields missing
}])

user_input = safe_input(user_input)

prediction = best_model.predict(user_input)
probability = best_model.predict_proba(user_input)

print(prediction, probability)
# Out:
# ['High'] [[0.7 0.3]]

# %% [markdown]
# # Saving the model for deployment

# %%
import os, joblib

print(os.getcwd())
os.makedirs("models", exist_ok=True)
joblib.dump(best_model, "best_model_pipeline.joblib")
print(os.listdir("models"))
# Out:
# C:\Users\Sujitkumar Bharati\ITvedant anaconda files\Graphura\Graphura Social Media DS-DA Project
# ['.ipynb_checkpoints', 'best_model_pipeline.joblib', 'best_model_v1.joblib']

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.2

# %%
import sys
print(sys.version)
# Out:
# 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]

# %%
import sys, sklearn, joblib

print(sys.version)
print(sklearn.__version__)

joblib.dump(best_model, "best_model_pipeline.joblib")
# Out:
# 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]
# 1.7.2
# ['best_model_pipeline.joblib']
